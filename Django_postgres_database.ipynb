# %%
import sqlalchemy
import pandas as pd

# %%
#Database details
user = 'postgres'
password = '123@abc'
db = 'KasaDaka'
host='127.0.0.1'
port=5432

# %%
#Function: Connection and Metadata
def connect(user, password, db, host, port):
    '''Returns a connection and a metadata object'''
    # We connect with the help of the PostgreSQL URL
    # postgresql://federer:grandestslam@localhost:5432/tennis
    url = 'postgresql://{}:{}@{}:{}/{}'
    url = url.format(user, password, host, port, db)

    # The return value of create_engine() is our connection object
    con = sqlalchemy.create_engine(url, client_encoding='utf8')

    # We then bind the connection to MetaData()
    meta = sqlalchemy.MetaData(bind=con, reflect=True)

    return con, meta

#Connect to database
#con = create_engine('postgresql://postgres:123@abc@127.0.0.1:5432/KasaDaka')
con, meta = connect(user, password, db, host, port)
# Out:
# /home/benny/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SADeprecationWarning: reflect=True is deprecate; please use the reflect() method.
#   del sys.path[0]

# %%
#Function: List all database tables
def tables(connection):
    table_names = connection.table_names()
    for table in table_names:
        print(table)
        
#Fuction: retrieve data from query 
def query(query):
    rs = con.execute(query)

    fa = rs.fetchall()
    for row in fa:
        for column in row:
            print(column)

#Function: Query to DataFrame
def query_df(query):
    #Execute query
    rs = con.execute(query)
    #Query results, and export to DataFrame
    df = pd.DataFrame(rs.fetchall())
    df.columns = rs.keys()
    #Close query
    rs.close()       
    #DataFrame with query results
    return df

# %%
#list database tables
tables(con)
# Out:
# django_migrations
# django_content_type
# auth_group_permissions
# auth_group
# auth_user_groups
# auth_permission
# auth_user_user_permissions
# auth_user
# django_admin_log
# service_development_voiceservice_supported_languages
# service_development_voiceservicesubelement
# service_development_voicefragment
# service_development_spokenuserinput
# service_development_language
# service_development_kasadakauser
# service_development_callsession
# service_development_userinputcategory
# service_development_voicelabel
# service_development_record
# service_development_voiceservice
# service_development_callsessionstep
# service_development_voiceserviceelement
# service_development_messagepresentation
# service_development_choice
# service_development_choiceoption
# django_session

# %%
#Query to DataFrame
query_df("SELECT * FROM service_development_callsession")
# Out:
#    id                            start                              end  \
# 0   1 2018-05-02 14:38:09.167000+02:00 2018-05-02 14:38:09.428000+02:00
#
#   caller_id  _language_id  service_id user_id
# 0     12345             2           1    None

# %%
#Query to DataFrame
query_df("SELECT * FROM service_development_callsessionstep")
# Out:
#    id                             time description  session_id  \
# 0   1 2018-05-02 14:38:09.431000+02:00        None           1
#
#    _visited_element_id
# 0                    8

# %%
#Retrieved data from query     
query("SELECT * FROM service_development_callsession")
# Out:
# 1
# 2018-05-02 14:38:09.167000+02:00
# 2018-05-02 14:38:09.428000+02:00
# 12345
# 2
# 1
# None

# %%
#Retrieved data from query     
query("SELECT * FROM service_development_callsessionstep")
# Out:
# 1
# 2018-05-02 14:38:09.431000+02:00
# None
# 1
# 8

# %%
#Retrieved data from query     
rs = con.execute("SELECT * FROM service_development_choiceoption")
print(rs.keys())

fa = rs.fetchall()
for row in fa:
    print(row)
# Out:
# ['voiceservicesubelement_ptr_id', '_redirect_id', 'parent_id']
# (12, 20, 11)
# (13, 24, 11)
# (32, 15, 31)
# (33, 15, 31)
# (34, 15, 31)
# (35, 15, 31)
# (38, 40, 37)
# (39, 43, 37)
# (41, 46, 40)
# (42, 49, 40)
# (44, 52, 43)
# (45, 55, 43)
# (47, 68, 46)
# (48, 62, 46)
# (50, 72, 49)
# (51, 62, 49)
# (53, 80, 52)
# (54, 62, 52)
# (56, 76, 55)
# (57, 62, 55)
# (59, 25, 58)
# (60, 26, 58)
# (61, 27, 58)
# (69, 66, 68)
# (70, 21, 68)
# (71, 24, 68)
# (73, 65, 72)
# (74, 21, 72)
# (75, 24, 72)
# (77, 64, 76)
# (78, 21, 76)
# (79, 24, 76)
# (81, 67, 80)
# (82, 21, 80)
# (83, 24, 80)
# ['id', 'time', 'description', 'session_id', '_visited_element_id']
# (1, datetime.datetime(2018, 5, 2, 14, 38, 9, 431000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None)), None, 1, 8)

# %%
rs = con.execute("SELECT * FROM service_development_callsessionstep")
print('Columns :', rs.keys(), '\n')
fa = rs.fetchall()


count = 0
for row in fa:
    count += 1
    for y, column in enumerate(row):
        print('row :', count)
        print('Column element', y, ': ', column, '\n')
        
    print('Number of entries :', count, '\n')
    print('row :',  row)
# Out:
# Columns : ['id', 'time', 'description', 'session_id', '_visited_element_id']
#
# row : 1
# Column element 0 :  1
#
# row : 1
# Column element 1 :  2018-05-02 14:38:09.431000+02:00
#
# row : 1
# Column element 2 :  None
#
# row : 1
# Column element 3 :  1
#
# row : 1
# Column element 4 :  8
#
# Number of entries : 1
#
# row : (1, datetime.datetime(2018, 5, 2, 14, 38, 9, 431000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=120, name=None)), None, 1, 8)

# %%
menu_choices = query_df("SELECT * FROM service_development_choiceoption")
menu_choices
# Out:
#     voiceservicesubelement_ptr_id  _redirect_id  parent_id
# 0                              12            20         11
# 1                              13            24         11
# 2                              32            15         31
# 3                              33            15         31
# 4                              34            15         31
# 5                              35            15         31
# 6                              38            40         37
# 7                              39            43         37
# 8                              41            46         40
# 9                              42            49         40
# 10                             44            52         43
# 11                             45            55         43
# 12                             47            68         46
# 13                             48            62         46
# 14                             50            72         49
# 15                             51            62         49
# 16                             53            80         52
# 17                             54            62         52
# 18                             56            76         55
# 19                             57            62         55
# 20                             59            25         58
# 21                             60            26         58
# 22                             61            27         58
# 23                             69            66         68
# 24                             70            21         68
# 25                             71            24         68
# 26                             73            65         72
# 27                             74            21         72
# 28                             75            24         72
# 29                             77            64         76
# 30                             78            21         76
# 31                             79            24         76
# 32                             81            67         80
# 33                             82            21         80
# 34                             83            24         80

# %%
rs = con.execute("SELECT * FROM service_development_choiceoption")

fa = rs.fetchall()

count = 0
for row in fa:
    count += 1
    for y, column in enumerate(row):
        print('row :', count)
        print('Column element', y, ': ', column, '\n')
        
    print('Number of entries :', count, '\n')
# Out:
# row : 1
# Column element 0 :  12
#
# row : 1
# Column element 1 :  20
#
# row : 1
# Column element 2 :  11
#
# Number of entries : 1
#
# row : 2
# Column element 0 :  13
#
# row : 2
# Column element 1 :  24
#
# row : 2
# Column element 2 :  11
#
# Number of entries : 2
#
# row : 3
# Column element 0 :  32
#
# row : 3
# Column element 1 :  15
#
# row : 3
# Column element 2 :  31
#
# Number of entries : 3
#
# row : 4
# Column element 0 :  33
#
# row : 4
# Column element 1 :  15
#
# row : 4
# Column element 2 :  31
#
# Number of entries : 4
#
# row : 5
# Column element 0 :  34
#
# row : 5
# Column element 1 :  15
#
# row : 5
# Column element 2 :  31
#
# Number of entries : 5
#
# row : 6
# Column element 0 :  35
#
# row : 6
# Column element 1 :  15
#
# row : 6
# Column element 2 :  31
#
# Number of entries : 6
#
# row : 7
# Column element 0 :  38
#
# row : 7
# Column element 1 :  40
#
# row : 7
# Column element 2 :  37
#
# Number of entries : 7
#
# row : 8
# Column element 0 :  39
#
# row : 8
# Column element 1 :  43
#
# row : 8
# Column element 2 :  37
#
# Number of entries : 8
#
# row : 9
# Column element 0 :  41
#
# row : 9
# Column element 1 :  46
#
# row : 9
# Column element 2 :  40
#
# Number of entries : 9
#
# row : 10
# Column element 0 :  42
#
# row : 10
# Column element 1 :  49
#
# row : 10
# Column element 2 :  40
#
# Number of entries : 10
#
# row : 11
# Column element 0 :  44
#
# row : 11
# Column element 1 :  52
#
# row : 11
# Column element 2 :  43
#
# Number of entries : 11
#
# row : 12
# Column element 0 :  45
#
# row : 12
# Column element 1 :  55
#
# row : 12
# Column element 2 :  43
#
# Number of entries : 12
#
# row : 13
# Column element 0 :  47
#
# row : 13
# Column element 1 :  68
#
# row : 13
# Column element 2 :  46
#
# Number of entries : 13
#
# row : 14
# Column element 0 :  48
#
# row : 14
# Column element 1 :  62
#
# row : 14
# Column element 2 :  46
#
# Number of entries : 14
#
# row : 15
# Column element 0 :  50
#
# row : 15
# Column element 1 :  72
#
# row : 15
# Column element 2 :  49
#
# Number of entries : 15
#
# row : 16
# Column element 0 :  51
#
# row : 16
# Column element 1 :  62
#
# row : 16
# Column element 2 :  49
#
# Number of entries : 16
#
# row : 17
# Column element 0 :  53
#
# row : 17
# Column element 1 :  80
#
# row : 17
# Column element 2 :  52
#
# Number of entries : 17
#
# row : 18
# Column element 0 :  54
#
# row : 18
# Column element 1 :  62
#
# row : 18
# Column element 2 :  52
#
# Number of entries : 18
#
# row : 19
# Column element 0 :  56
#
# row : 19
# Column element 1 :  76
#
# row : 19
# Column element 2 :  55
#
# Number of entries : 19
#
# row : 20
# Column element 0 :  57
#
# row : 20
# Column element 1 :  62
#
# row : 20
# Column element 2 :  55
#
# Number of entries : 20
#
# row : 21
# Column element 0 :  59
#
# row : 21
# Column element 1 :  25
#
# row : 21
# Column element 2 :  58
#
# Number of entries : 21
#
# row : 22
# Column element 0 :  60
#
# row : 22
# Column element 1 :  26
#
# row : 22
# Column element 2 :  58
#
# Number of entries : 22
#
# row : 23
# Column element 0 :  61
#
# row : 23
# Column element 1 :  27
#
# row : 23
# Column element 2 :  58
#
# Number of entries : 23
#
# row : 24
# Column element 0 :  69
#
# row : 24
# Column element 1 :  66
#
# row : 24
# Column element 2 :  68
#
# Number of entries : 24
#
# row : 25
# Column element 0 :  70
#
# row : 25
# Column element 1 :  21
#
# row : 25
# Column element 2 :  68
#
# Number of entries : 25
#
# row : 26
# Column element 0 :  71
#
# row : 26
# Column element 1 :  24
#
# row : 26
# Column element 2 :  68
#
# Number of entries : 26
#
# row : 27
# Column element 0 :  73
#
# row : 27
# Column element 1 :  65
#
# row : 27
# Column element 2 :  72
#
# Number of entries : 27
#
# row : 28
# Column element 0 :  74
#
# row : 28
# Column element 1 :  21
#
# row : 28
# Column element 2 :  72
#
# Number of entries : 28
#
# row : 29
# Column element 0 :  75
#
# row : 29
# Column element 1 :  24
#
# row : 29
# Column element 2 :  72
#
# Number of entries : 29
#
# row : 30
# Column element 0 :  77
#
# row : 30
# Column element 1 :  64
#
# row : 30
# Column element 2 :  76
#
# Number of entries : 30
#
# row : 31
# Column element 0 :  78
#
# row : 31
# Column element 1 :  21
#
# row : 31
# Column element 2 :  76
#
# Number of entries : 31
#
# row : 32
# Column element 0 :  79
#
# row : 32
# Column element 1 :  24
#
# row : 32
# Column element 2 :  76
#
# Number of entries : 32
#
# row : 33
# Column element 0 :  81
#
# row : 33
# Column element 1 :  67
#
# row : 33
# Column element 2 :  80
#
# Number of entries : 33
#
# row : 34
# Column element 0 :  82
#
# row : 34
# Column element 1 :  21
#
# row : 34
# Column element 2 :  80
#
# Number of entries : 34
#
# row : 35
# Column element 0 :  83
#
# row : 35
# Column element 1 :  24
#
# row : 35
# Column element 2 :  80
#
# Number of entries : 35

# %%
session = meta.tables['service_development_choiceoption']
#session = meta.tables['django_session']
for col in session.c:
    print(col)
    
print('\n', session.columns.keys(), '\n')
print(repr(meta.tables['service_development_choiceoption']), '\n')
# Out:
# service_development_choiceoption.voiceservicesubelement_ptr_id
# service_development_choiceoption._redirect_id
# service_development_choiceoption.parent_id
#
#  ['voiceservicesubelement_ptr_id', '_redirect_id', 'parent_id']
#
# Table('service_development_choiceoption', MetaData(bind=Engine(postgresql://postgres:***@127.0.0.1:5432/KasaDaka)), Column('voiceservicesubelement_ptr_id', INTEGER(), ForeignKey('service_development_voiceservicesubelement.id'), table=<service_development_choiceoption>, primary_key=True, nullable=False), Column('_redirect_id', INTEGER(), ForeignKey('service_development_voiceserviceelement.voiceservicesubelement_ptr_id'), table=<service_development_choiceoption>), Column('parent_id', INTEGER(), ForeignKey('service_development_choice.voiceserviceelement_ptr_id'), table=<service_development_choiceoption>, nullable=False), schema=None)

# %%
stmt = 'SELECT * FROM service_development_choice'
query(stmt)

rs = con.execute(stmt)
print(rs.keys())

fa = rs.fetchall()

count = 0
for row in fa:
    count += 1
    for y, column in enumerate(row):
        print('row :', count)
        print('Column element', y, ': ', column, '\n')
        
    print('Number of entries :', count, '\n')
# Out:
# 11
# 31
# 37
# 40
# 43
# 46
# 49
# 52
# 55
# 58
# 68
# 72
# 76
# 80
# ['voiceserviceelement_ptr_id']
# row : 1
# Column element 0 :  11
#
# Number of entries : 1
#
# row : 2
# Column element 0 :  31
#
# Number of entries : 2
#
# row : 3
# Column element 0 :  37
#
# Number of entries : 3
#
# row : 4
# Column element 0 :  40
#
# Number of entries : 4
#
# row : 5
# Column element 0 :  43
#
# Number of entries : 5
#
# row : 6
# Column element 0 :  46
#
# Number of entries : 6
#
# row : 7
# Column element 0 :  49
#
# Number of entries : 7
#
# row : 8
# Column element 0 :  52
#
# Number of entries : 8
#
# row : 9
# Column element 0 :  55
#
# Number of entries : 9
#
# row : 10
# Column element 0 :  58
#
# Number of entries : 10
#
# row : 11
# Column element 0 :  68
#
# Number of entries : 11
#
# row : 12
# Column element 0 :  72
#
# Number of entries : 12
#
# row : 13
# Column element 0 :  76
#
# Number of entries : 13
#
# row : 14
# Column element 0 :  80
#
# Number of entries : 14

# %%
#Fuction: retrieve data from query 
def query(query):
    qlist = []
    rs = con.execute(query)

    fa = rs.fetchall()
    #for key in rs.keys():
    for count, row in enumerate(fa):
        for count2, column in enumerate(row):
            #print(rs.keys()[count2])
            #print(fa[count][count2])
            qlist.append(str(rs.keys()[count2]) + ":  " + str(fa[count][count2]))
    return qlist
            
            
            
            #qlist.append(column)
            #print(fa[count]) 

query("SELECT * FROM service_development_callsession")
# Out:
# ['id:  1',
#  'start:  2018-05-02 14:38:09.167000+02:00',
#  'end:  2018-05-02 14:38:09.428000+02:00',
#  'caller_id:  12345',
#  '_language_id:  2',
#  'service_id:  1',
#  'user_id:  None']

# %%
#Fuction: retrieve data from query 
def query(query):
    rs = con.execute(query)

    fa = rs.fetchall()
    for row in fa:
        for column in row:
            print(column)

query("SELECT * FROM service_development_callsession")
# Out:
# 1
# 2018-05-02 14:38:09.167000+02:00
# 2018-05-02 14:38:09.428000+02:00
# 12345
# 2
# 1
# None
